# %%
import pandas as pd
import numpy as np
import wordcloud as wc
from matplotlib import pyplot as plt

data = pd.read_excel('data.xlsx', sheet_name = 'Lab 1 - Web Intelligence Public')
data.head(5)
# Out:
#                                              Authors  \
# 0  Vithya G., Naren J., Vikas Reddy K., Raghunand...
# 1  Lin S., Gao J., Zhang S., He X., Sheng Y., Che...
# 2                         [No author name available]
# 3                         [No author name available]
# 4  Liu H., Ning H., Mu Q., Zheng Y., Zeng J., Yan...
#
#                                         Author(s) ID  \
# 0   49362399800;55671230800;57214314483;57214315455;
# 1  57191409679;57209472530;57209473974;5643781620...
# 2                           [No author id available]
# 3                           [No author id available]
# 4  56872078600;9232973200;57187872300;57187332300...
#
#                                                Title  Year  \
# 0  A study on web intelligence for the internet o...  2020
# 1  A continuous learning method for recognizing n...  2020
# 2  Proceedings - 2019 IEEE/WIC/ACM International ...  2019
# 3  Proceedings - 2019 IEEE/WIC/ACM International ...  2019
# ...

# %%
data_2000_2006 = data[data['Year'].between(2000 ,2006 ,inclusive = True)]

# %%
# author keywords wordcloud
author_keywords_list_raw = data_2000_2006['Author Keywords'].dropna().tolist()
author_keyword_list = []
for keywlist in author_keywords_list_raw:
    for word in keywlist.split(';'):
        author_keyword_list.append(word.lower().strip())
author_frequencies = pd.Series(author_keyword_list).value_counts()
auth_wordcloud = wc.WordCloud().generate_from_frequencies(author_frequencies)
plt.imshow(auth_wordcloud)
plt.axis("off")
plt.show()

# %%
author_frequencies
# Out:
# web intelligence               24
# semantic web                   10
# web mining                      7
# artificial intelligence         4
# fuzzy logic                     4
#                                ..
# humans                          1
# autonomy-oriented computing     1
# formal concept analysis         1
# myspiders                       1
# adaptive interface              1
# Length: 207, dtype: int64

# %%
# index keywords wordcloud
index_keywords_list_raw = data_2000_2006['Index Keywords'].dropna().tolist()
index_keyword_list = []
for keywlist in index_keywords_list_raw:
    for word in keywlist.split(';'):
        index_keyword_list.append(word.lower().strip())
index_frequencies = pd.Series(index_keyword_list).value_counts()
index_wordcloud = wc.WordCloud().generate_from_frequencies(index_frequencies)
plt.imshow(index_wordcloud)
plt.axis("off")
plt.show()

# %%
index_frequencies
# Out:
# world wide web             89
# web intelligence           71
# artificial intelligence    64
# data mining                33
# intelligent agents         28
#                            ..
# boolean operators           1
# external knowledge          1
# intelligence                1
# web structure               1
# cisco (co)                  1
# Length: 779, dtype: int64

# %%
#affi_list = data_2000_2006['Affiliations'].dropna().tolist()
#school_list = []
#for l in affi_list:
#    school_list.append(l.split(',')[0])
#field_list = ', '.join(affi_list)
#field_list
#wordlist = ['Institute', 'Department', 'School', 'Faculty', 'University']

#for word in wordlist:
#    print([s for s in school_list if word in s])
# Out:
# ['IEEE; IFSA; Systems Research Institute', 'Maebashi Institute of Technology', 'International WIC Institute', 'International WIC Institute', 'International WIC Institute', 'International WIC Institute', 'International WIC Institute', 'International WIC Institute', 'Graduate Institute of Information Management', 'Institute of Computer Science', 'Institute for Software Science', 'Institute of Artificial Intelligence', 'Institute for Software Technology and Mutimedia Systems']
# ...
