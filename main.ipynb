# %%
import pandas as pd
import numpy as np

data = pd.read_excel('data.xlsx', sheet_name = 'Lab 1 - Web Intelligence Public')
data.head(5)
# Out:
#                                              Authors  \
# 0  Vithya G., Naren J., Vikas Reddy K., Raghunand...
# 1  Lin S., Gao J., Zhang S., He X., Sheng Y., Che...
# 2                         [No author name available]
# 3                         [No author name available]
# 4  Liu H., Ning H., Mu Q., Zheng Y., Zeng J., Yan...
#
#                                         Author(s) ID  \
# 0   49362399800;55671230800;57214314483;57214315455;
# 1  57191409679;57209472530;57209473974;5643781620...
# 2                           [No author id available]
# 3                           [No author id available]
# 4  56872078600;9232973200;57187872300;57187332300...
#
#                                                Title  Year  \
# 0  A study on web intelligence for the internet o...  2020
# 1  A continuous learning method for recognizing n...  2020
# 2  Proceedings - 2019 IEEE/WIC/ACM International ...  2019
# 3  Proceedings - 2019 IEEE/WIC/ACM International ...  2019
# 4                        A review of the smart world  2019
#
#                                         Source title Volume Issue Art. No.  \
# 0  International Journal of Psychosocial Rehabili...     23     1      NaN
# 1                                     World Wide Web    NaN   NaN      NaN
# 2  Proceedings - 2019 IEEE/WIC/ACM International ...    NaN   NaN      NaN
# 3  Proceedings - 2019 IEEE/WIC/ACM International ...    NaN   NaN      NaN
# 4                 Future Generation Computer Systems     96   NaN      NaN
#
#   Page start Page end  ...           ISBN  CODEN PubMed ID  \
# 0        394      399  ...            NaN    NaN       NaN
# 1        NaN      NaN  ...            NaN    NaN       NaN
# 2        NaN      NaN  ...  9781450369343    NaN       NaN
# 3        NaN      NaN  ...  9781450369886    NaN       NaN
# 4        678      691  ...            NaN  FGCSE       NaN
#
#   Language of Original Document  \
# 0                       English
# 1                       English
# 2                       English
# 3                       English
# 4                       English
#
#                             Abbreviated Source Title      Document Type  \
# 0                          Int. J. Psychosoc. Rehab.            Article
# 1                                     World Wide Web            Article
# 2    Proc. - IEEE/WIC/ACM Int. Conf. Web Intell., WI  Conference Review
# 3  Proc. - IEEE/WIC/ACM Int. Conf. Web Intell. Wo...  Conference Review
# 4                           Future Gener Comput Syst            Article
#
#   Publication Stage Access Type  Source                 EID
# 0             Final         NaN  Scopus  2-s2.0-85078623770
# 1  Article in Press         NaN  Scopus  2-s2.0-85079717044
# 2             Final         NaN  Scopus  2-s2.0-85074789229
# 3             Final         NaN  Scopus  2-s2.0-85074320724
# 4             Final         NaN  Scopus  2-s2.0-85029474758
#
# [5 rows x 33 columns]

# %%
data[data['Year'].between(2000 ,2006 ,inclusive = True)]
# Out:
#                                    Authors  \
# 644                            Kacprzyk J.
# 645                Zuccala A., Thelwall M.
# 646             [No author name available]
# 647                           Nikravesh M.
# 648                               Lin T.Y.
# ..                                     ...
# 799  Yao Y.Y., Zhong N., Liu J., Ohsuga S.
# 800                             Cercone N.
# 801             [No author name available]
# 802                           Mizoguchi R.
# 803  Zhong N., Liu J., Yao Y.Y., Ohsuga S.
#
#                                        Author(s) ID  \
# 644                                    26643457100;
# 645                        24382144000;55396590500;
# 646                        [No author id available]
# 647                                     6701543332;
# 648                                    57200571771;
# ..                                              ...
# 799  7403567566;7102138219;35230430700;55679296500;
# 800                                     7003403956;
# 801                        [No author id available]
# 802                                     7006017969;
# 803  7102138219;35230430700;7403567566;55679296500;
#
#                                                  Title  Year  \
# 644  Web intelligence, business intelligence and de...  2006
# 645    LexiURL Web link analysis for digital libraries  2006
# 646  Proceedings - 30th Annual International Comput...  2006
# 647  Chapter 22 Enhancing the power of the internet...  2006
# 648  Introduction to panels on E-security, granular...  2006
# ..                                                 ...   ...
# 799  Web intelligence (WI): Research challenges and...  2001
# 800  From computational intelligence to web intelli...  2001
# 801  1st Asia-Pacific Conference on Web Intelligenc...  2001
# 802  Ontological engineering: Foundation of the nex...  2001
# 803                              Web Intelligence (WI)  2000
#
#                                           Source title Volume Issue Art. No.  \
# 644                           IEEE Intelligent Systems    NaN   NaN  4155389
# 645  Proceedings of the ACM/IEEE Joint Conference o...   2006   NaN      NaN
# 646  Proceedings - International Computer Software ...      1   NaN      NaN
# 647                             Capturing Intelligence      1     C      NaN
# 648  Proceedings - International Computer Software ...      1   NaN  4020045
# ..                                                 ...    ...   ...      ...
# 799  Lecture Notes in Computer Science (including s...   2198   NaN      NaN
# 800  Lecture Notes in Computer Science (including s...   2198   NaN      NaN
# 801  Lecture Notes in Computer Science (including s...   2198   NaN      NaN
# 802  Lecture Notes in Computer Science (including s...   2198   NaN      NaN
# 803  Proceedings - IEEE Computer Society's Internat...    NaN   NaN      NaN
#
#     Page start Page end  ...                       ISBN  CODEN PubMed ID  \
# 644          3      NaN  ...  1424401968; 9781424401963    NaN       NaN
# 645        371      NaN  ...  1595933549; 9781595933546    NaN       NaN
# 646        NaN      NaN  ...  0769526551; 9780769526553  PSICD       NaN
# 647        441      464  ...                        NaN    NaN       NaN
# 648         21      NaN  ...  0769526551; 9780769526553  PSICD       NaN
# ..         ...      ...  ...                        ...    ...       ...
# 799        NaN      NaN  ...  3540427309; 9783540427308    NaN       NaN
# 800         30       42  ...  3540427309; 9783540427308    NaN       NaN
# 801          1      614  ...  3540427309; 9783540427308    NaN       NaN
# 802         44       57  ...  3540427309; 9783540427308    NaN       NaN
# 803        469      470  ...                        NaN    NaN       NaN
#
#     Language of Original Document  \
# 644                       English
# 645                       English
# 646                       English
# 647                       English
# 648                       English
# ..                            ...
# 799                       English
# 800                       English
# 801                       English
# 802                       English
# 803                       English
#
#                               Abbreviated Source Title      Document Type  \
# 644                                 IEEE Intell. Syst.   Conference Paper
# 645            Proc. ACM IEEE Joint Conf. Digit. Libr.   Conference Paper
# 646                 Proc Int Comput Software Appl Conf  Conference Review
# 647                                  Capturing Intell.            Article
# 648                 Proc Int Comput Software Appl Conf   Conference Paper
# ..                                                 ...                ...
# 799                           Lect. Notes Comput. Sci.   Conference Paper
# 800                           Lect. Notes Comput. Sci.   Conference Paper
# 801                           Lect. Notes Comput. Sci.  Conference Review
# 802                           Lect. Notes Comput. Sci.   Conference Paper
# 803  Proc IEEE Comput Soc Int Comput Software Appl ...            Article
#
#     Publication Stage Access Type  Source                 EID
# 644             Final         NaN  Scopus  2-s2.0-46249104546
# 645             Final         NaN  Scopus  2-s2.0-34247187427
# 646             Final         NaN  Scopus  2-s2.0-34247505924
# 647             Final         NaN  Scopus  2-s2.0-77957076940
# 648             Final         NaN  Scopus  2-s2.0-34247541405
# ..                ...         ...     ...                 ...
# 799             Final         NaN  Scopus  2-s2.0-84942578395
# 800             Final         NaN  Scopus  2-s2.0-84942568493
# 801             Final         NaN  Scopus  2-s2.0-84942693215
# 802             Final         NaN  Scopus  2-s2.0-84942614126
# 803             Final         NaN  Scopus   2-s2.0-0034498334
#
# [160 rows x 33 columns]
